# %% [markdown]
# # Import the pandas library
# # Read the data company.csv in pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('company.csv')

# %% [markdown]
# # Find the dimension of given data

# %%
df.shape
# Out:
# (148, 6)

# %% [markdown]
# # List down all the columns in data frame

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place', 'Country', 'Gender'], dtype='object')

# %% [markdown]
# # List the top 10 rows in datframe

# %%
df.head(10)
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0
# 5  Infosys   NaN  5000.0  Calcutta   India       0
# 6      TCS   NaN  6000.0   Chennai   India       1
# 7  Infosys  23.0  7000.0    Mumbai   India       1
# 8      TCS  34.0  8000.0  Calcutta   India       1
# 9      CTS  45.0  9000.0     Delhi   India       0

# %% [markdown]
# # List the last 15 rows in dataframe

# %%
df.tail(15)
# Out:
#                        Company   Age  Salary      Place Country  Gender
# 133                        NaN  22.0  8943.0    Chennai   India       0
# 134  Tata Consultancy Services  31.0  8345.0     Mumbai   India       0
# 135                        CTS  40.0  9284.0   Calcutta   India       1
# 136                        NaN   NaN     NaN      Delhi   India       0
# 137                        CTS  31.0  2034.0     Mumbai   India       0
# 138                        CTS  44.0  3033.0     Cochin   India       0
# 139                 Congnizant  22.0  2934.0      Noida   India       0
# 140                    Infosys  44.0  4034.0  Hyderabad   India       0
# 141                        TCS  33.0  5034.0   Calcutta   India       0
# 142            Infosys Pvt Lmt  22.0  8202.0     Mumbai   India       0
# 143                        TCS  33.0  9024.0   Calcutta   India       1
# 144                    Infosys  22.0  8787.0   Calcutta   India       1
# 145                    Infosys  44.0  4034.0      Delhi   India       1
# 146                        TCS  33.0  5034.0     Mumbai   India       1
# 147                    Infosys  22.0  8202.0     Cochin   India       0

# %% [markdown]
# # Find the number of rows in dataframe

# %%
len(df)
# Out:
# 148

# %%
len(df.index)
# Out:
# 148

# %% [markdown]
# # Check the information of dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 6 columns):
# Company    140 non-null object
# Age        130 non-null float64
# Salary     124 non-null float64
# Place      134 non-null object
# Country    148 non-null object
# Gender     148 non-null int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.0+ KB

# %% [markdown]
# # Check the basic Statistics of Dataframe. Give your inference from the stats

# %%
df.describe()
# Out:
#               Age       Salary      Gender
# count  130.000000   124.000000  148.000000
# mean    30.484615  5312.467742    0.222973
# std     11.096640  2573.764683    0.417654
# min      0.000000  1089.000000    0.000000
# 25%     22.000000  3030.000000    0.000000
# 50%     32.500000  5000.000000    0.000000
# 75%     37.750000  8000.000000    0.000000
# max     54.000000  9876.000000    1.000000

# %% [markdown]
# # Retrieve 20 to 100 rows and Company and age usig iloc

# %%
df.iloc[20:100,0:2] #using iloc
# Out:
#             Company   Age
# 20              TCS  37.0
# 21          Infosys  50.0
# 22              TCS  21.0
# 23          Infosys   NaN
# 24              TCS   NaN
# 25          Infosys  23.0
# 26              TCS  34.0
# 27              CTS  45.0
# 28              CTS  23.0
# 29              CTS  35.0
# 30              CTS  46.0
# 31              CTS  20.0
# 32          Infosys  45.0
# 33              TCS  36.0
# 34          Infosys  26.0
# 35              TCS  35.0
# 36              TCS  32.0
# 37              NaN  35.0
# 38              TCS  34.0
# 39          Infosys  41.0
# 40              TCS  24.0
# 41          Infosys   NaN
# 42              TCS   NaN
# 43          Infosys  25.0
# 44              TCS  35.0
# 45              CTS  46.0
# 46              CTS  24.0
# 47              CTS  32.0
# 48              CTS  43.0
# 49              CTS  19.0
# ..              ...   ...
# 70  Infosys Pvt Lmt  21.0
# 71              TCS  34.0
# 72              TCS  24.0
# 73          Infosys  34.0
# 74              TCS  37.0
# 75          Infosys  44.0
# 76              TCS  32.0
# 77          Infosys   NaN
# 78              TCS   NaN
# 79          Infosys  26.0
# 80              TCS  32.0
# 81              CTS  43.0
# 82              CTS  22.0
# 83              CTS  33.0
# 84              CTS  43.0
# 85              CTS  17.0
# 86          Infosys  41.0
# 87              TCS  21.0
# 88          Infosys   0.0
# 89              TCS  36.0
# 90              TCS  21.0
# 91          Infosys  34.0
# 92              TCS   0.0
# 93          Infosys  54.0
# 94              TCS  22.0
# 95          Infosys   NaN
# 96              TCS   NaN
# 97          Infosys  22.0
# 98              TCS  33.0
# 99              CTS  44.0
#
# [80 rows x 2 columns]

# %% [markdown]
# # Retrieve 20 to 100 rows and Company and age usig loc

# %%
df.loc[20:100,['Company','Age']] #using loc
# Out:
#      Company   Age
# 20       TCS  37.0
# 21   Infosys  50.0
# 22       TCS  21.0
# 23   Infosys   NaN
# 24       TCS   NaN
# 25   Infosys  23.0
# 26       TCS  34.0
# 27       CTS  45.0
# 28       CTS  23.0
# 29       CTS  35.0
# 30       CTS  46.0
# 31       CTS  20.0
# 32   Infosys  45.0
# 33       TCS  36.0
# 34   Infosys  26.0
# 35       TCS  35.0
# 36       TCS  32.0
# 37       NaN  35.0
# 38       TCS  34.0
# 39   Infosys  41.0
# 40       TCS  24.0
# 41   Infosys   NaN
# 42       TCS   NaN
# 43   Infosys  25.0
# 44       TCS  35.0
# 45       CTS  46.0
# 46       CTS  24.0
# 47       CTS  32.0
# 48       CTS  43.0
# 49       CTS  19.0
# ..       ...   ...
# 71       TCS  34.0
# 72       TCS  24.0
# 73   Infosys  34.0
# 74       TCS  37.0
# 75   Infosys  44.0
# 76       TCS  32.0
# 77   Infosys   NaN
# 78       TCS   NaN
# 79   Infosys  26.0
# 80       TCS  32.0
# 81       CTS  43.0
# 82       CTS  22.0
# 83       CTS  33.0
# 84       CTS  43.0
# 85       CTS  17.0
# 86   Infosys  41.0
# 87       TCS  21.0
# 88   Infosys   0.0
# 89       TCS  36.0
# 90       TCS  21.0
# 91   Infosys  34.0
# 92       TCS   0.0
# 93   Infosys  54.0
# 94       TCS  22.0
# 95   Infosys   NaN
# 96       TCS   NaN
# 97   Infosys  22.0
# 98       TCS  33.0
# 99       CTS  44.0
# 100      CTS  22.0
#
# [81 rows x 2 columns]

# %% [markdown]
# # Change the data in 100 row and Place as 'Noida'

# %%
df.loc[100,'Place'] = 'Noida'

# %%
df.loc[100]
# Out:
# Company      CTS
# Age           22
# Salary       NaN
# Place      Noida
# Country    India
# Gender         0
# Name: 100, dtype: object

# %% [markdown]
# # Change the column 'Place' to 'City'

# %%
df.rename(columns={'Place':'City'},inplace=True)

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'City', 'Country', 'Gender'], dtype='object')

# %% [markdown]
# # List down the unique data in each columns and find length of unique data

# %%
df.apply(lambda x:print(x.value_counts()),axis=0)
# Out:
# TCS                          53
# Infosys                      45
# CTS                          36
# Tata Consultancy Services     2
# Congnizant                    2
# Infosys Pvt Lmt               2
# Name: Company, dtype: int64
# 22.0    16
# 33.0    13
# 44.0    10
# 21.0     8
# 23.0     8
# 34.0     8
# 32.0     7
# 35.0     6
# 0.0      6
# 41.0     5
# 43.0     4
# 24.0     4
# 45.0     4
# 25.0     3
# 36.0     3
# 40.0     3
# 31.0     3
# 20.0     3
# 30.0     2
# 26.0     2
# 37.0     2
# 46.0     2
# 50.0     2
# 18.0     1
# 17.0     1
# 38.0     1
# 19.0     1
# 51.0     1
# 54.0     1
# Name: Age, dtype: int64
# 3000.0    9
# 5000.0    6
# 4034.0    5
# 8202.0    5
# 5034.0    5
# 3184.0    4
# 7084.0    4
# 8787.0    4
# 1234.0    4
# 3045.0    4
# 5835.0    4
# 9024.0    4
# 8943.0    4
# 9284.0    4
# 2034.0    4
# 4824.0    4
# 2934.0    4
# 1089.0    4
# 2300.0    4
# 8345.0    4
# 7000.0    3
# 3030.0    3
# 8000.0    3
# 9000.0    3
# 6000.0    3
# 4000.0    2
# 9876.0    2
# 3234.0    2
# 7654.0    2
# 5435.0    1
# 4345.0    1
# 3033.0    1
# 5654.0    1
# 5098.0    1
# 3454.0    1
# 6543.0    1
# 6544.0    1
# 5555.0    1
# 4324.0    1
# 5009.0    1
# Name: Salary, dtype: int64
# Mumbai        37
# Calcutta      33
# Chennai       14
# Delhi         14
# Cochin        12
# Noida          9
# Hyderabad      8
# Podicherry     3
# Pune           2
# Nagpur         1
# Bhopal         1
# Name: City, dtype: int64
# India    148
# Name: Country, dtype: int64
# 0    115
# 1     33
# Name: Gender, dtype: int64
# Company    None
# Age        None
# Salary     None
# City       None
# Country    None
# Gender     None
# dtype: object

# %%
df.apply(lambda x:x.nunique(),axis=0)
# Out:
# Company     6
# Age        29
# Salary     40
# City       11
# Country     1
# Gender      2
# dtype: int64

# %% [markdown]
# # Rename all the possible labels of column in Company as three labels
# # TCS
# # CTS
# # Infosys

# %%
df.Company.unique()
# Out:
# array(['TCS', 'Infosys', 'CTS', nan, 'Tata Consultancy Services',
#        'Congnizant', 'Infosys Pvt Lmt'], dtype=object)

# %%
df['Company'].replace({'Tata Consultancy Services':'TCS','Congnizant':'CTS','Infosys Pvt Lmt':'Infosys'},inplace=True)

# %%
df.Company.value_counts()
# Out:
# TCS        55
# Infosys    47
# CTS        38
# Name: Company, dtype: int64

# %% [markdown]
# # Where ever you see age as 0 replace with NA
#
# # ##Hint df[df.Age==20] = np.isnan

# %%
df[df.Age==0]
# Out:
#      Company  Age  Salary        City Country  Gender
# 88   Infosys  0.0  3030.0    Calcutta   India       0
# 92       TCS  0.0  3045.0       Delhi   India       0
# 101      CTS  0.0  2034.0  Podicherry   India       0
# 107      TCS  0.0  9024.0     Chennai   India       1
# 111  Infosys  0.0  3234.0      Mumbai   India       0
# 121      CTS  0.0  1234.0    Calcutta   India       0

# %%
import numpy as np
df.replace({'Age':{0:np.nan}},inplace=False)
# Out:
#      Company   Age  Salary        City Country  Gender
# 0        TCS  20.0     NaN     Chennai   India       0
# 1    Infosys  30.0     NaN      Mumbai   India       0
# 2        TCS  35.0  2300.0    Calcutta   India       0
# 3    Infosys  40.0  3000.0       Delhi   India       0
# 4        TCS  23.0  4000.0      Mumbai   India       0
# 5    Infosys   NaN  5000.0    Calcutta   India       0
# 6        TCS   NaN  6000.0     Chennai   India       1
# 7    Infosys  23.0  7000.0      Mumbai   India       1
# 8        TCS  34.0  8000.0    Calcutta   India       1
# 9        CTS  45.0  9000.0       Delhi   India       0
# 10       CTS  23.0     NaN      Mumbai   India       0
# 11       CTS  34.0  1089.0    Calcutta   India       0
# 12       CTS  45.0     NaN     Chennai   India       0
# 13       CTS  18.0  1234.0      Mumbai   India       0
# 14   Infosys  40.0  3000.0    Calcutta   India       0
# 15       TCS  23.0  3000.0       Delhi   India       0
# 16   Infosys  23.0  3030.0  Podicherry   India       0
# 17       TCS  34.0  5000.0      Cochin   India       0
# 18       TCS  22.0     NaN     Chennai   India       0
# 19   Infosys  32.0     NaN      Mumbai   India       0
# 20       TCS  37.0  3045.0    Calcutta   India       0
# 21   Infosys  50.0  3184.0       Delhi   India       0
# 22       TCS  21.0  4824.0      Mumbai   India       0
# 23   Infosys   NaN  5835.0      Cochin   India       0
# 24       TCS   NaN  7084.0     Chennai   India       1
# 25   Infosys  23.0  8943.0      Mumbai   India       1
# 26       TCS  34.0  8345.0    Calcutta   India       1
# 27       CTS  45.0  9284.0       Delhi   India       1
# 28       CTS  23.0  9876.0      Mumbai   India       1
# 29       CTS  35.0  2034.0      Cochin   India       0
# ..       ...   ...     ...         ...     ...     ...
# 118      CTS  22.0     NaN         NaN   India       0
# 119      CTS  33.0  1089.0       Noida   India       0
# 120      CTS  44.0     NaN   Hyderabad   India       0
# 121      CTS   NaN  1234.0    Calcutta   India       0
# 122  Infosys  44.0  3234.0      Mumbai   India       0
# 123      NaN   NaN  3454.0    Calcutta   India       0
# 124  Infosys  22.0  8787.0    Calcutta   India       1
# 125      TCS  33.0  5654.0         NaN   India       1
# 126      TCS  20.0  5009.0         NaN   India       1
# 127  Infosys  30.0  5098.0       Noida   India       0
# 128      TCS  33.0  3045.0   Hyderabad   India       0
# 129  Infosys  50.0  3184.0    Calcutta   India       0
# 130      TCS  21.0  4824.0      Mumbai   India       0
# 131  Infosys   NaN  5835.0      Mumbai   India       0
# 132      TCS   NaN  7084.0      Cochin   India       1
# 133      NaN  22.0  8943.0     Chennai   India       0
# 134      TCS  31.0  8345.0      Mumbai   India       0
# 135      CTS  40.0  9284.0    Calcutta   India       1
# 136      NaN   NaN     NaN       Delhi   India       0
# 137      CTS  31.0  2034.0      Mumbai   India       0
# 138      CTS  44.0  3033.0      Cochin   India       0
# 139      CTS  22.0  2934.0       Noida   India       0
# 140  Infosys  44.0  4034.0   Hyderabad   India       0
# 141      TCS  33.0  5034.0    Calcutta   India       0
# 142  Infosys  22.0  8202.0      Mumbai   India       0
# 143      TCS  33.0  9024.0    Calcutta   India       1
# 144  Infosys  22.0  8787.0    Calcutta   India       1
# 145  Infosys  44.0  4034.0       Delhi   India       1
# 146      TCS  33.0  5034.0      Mumbai   India       1
# 147  Infosys  22.0  8202.0      Cochin   India       0
#
# [148 rows x 6 columns]

# %%
df[df.Age==0]
# Out:
#      Company  Age  Salary        City Country  Gender
# 88   Infosys  0.0  3030.0    Calcutta   India       0
# 92       TCS  0.0  3045.0       Delhi   India       0
# 101      CTS  0.0  2034.0  Podicherry   India       0
# 107      TCS  0.0  9024.0     Chennai   India       1
# 111  Infosys  0.0  3234.0      Mumbai   India       0
# 121      CTS  0.0  1234.0    Calcutta   India       0

# %%
df[df['Age'].isnull()]
# Out:
#      Company  Age  Salary       City Country  Gender
# 5    Infosys  NaN  5000.0   Calcutta   India       0
# 6        TCS  NaN  6000.0    Chennai   India       1
# 23   Infosys  NaN  5835.0     Cochin   India       0
# 24       TCS  NaN  7084.0    Chennai   India       1
# 41   Infosys  NaN  5000.0        NaN   India       0
# 42       TCS  NaN  6000.0        NaN   India       0
# 59   Infosys  NaN  5835.0     Mumbai   India       0
# 60       TCS  NaN  7084.0   Calcutta   India       0
# 77   Infosys  NaN  5000.0  Hyderabad   India       0
# 78       TCS  NaN  6000.0   Calcutta   India       0
# 95   Infosys  NaN  5835.0    Chennai   India       0
# 96       TCS  NaN  7084.0     Mumbai   India       1
# 113  Infosys  NaN  5435.0    Chennai   India       0
# 114      TCS  NaN  5555.0     Mumbai   India       0
# 123      NaN  NaN  3454.0   Calcutta   India       0
# 131  Infosys  NaN  5835.0     Mumbai   India       0
# 132      TCS  NaN  7084.0     Cochin   India       1
# 136      NaN  NaN     NaN      Delhi   India       0

# %% [markdown]
# # Check how many duplicated data is there?

# %%
df[df.duplicated()]
# Out:
#      Company   Age  Salary      City Country  Gender
# 84       CTS  43.0     NaN    Mumbai   India       0
# 130      TCS  21.0  4824.0    Mumbai   India       0
# 131  Infosys   NaN  5835.0    Mumbai   India       0
# 144  Infosys  22.0  8787.0  Calcutta   India       1

# %%
df[df.duplicated()].shape[0]
# Out:
# 4

# %%
df.shape
# Out:
# (148, 6)

# %% [markdown]
# # Remove all duplicated rowise data

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (144, 6)

# %% [markdown]
# # Remove the column 'Country'

# %%
df.drop('Country',axis=1)
# Out:
#      Company   Age  Salary        City  Gender
# 0        TCS  20.0     NaN     Chennai       0
# 1    Infosys  30.0     NaN      Mumbai       0
# 2        TCS  35.0  2300.0    Calcutta       0
# 3    Infosys  40.0  3000.0       Delhi       0
# 4        TCS  23.0  4000.0      Mumbai       0
# 5    Infosys   NaN  5000.0    Calcutta       0
# 6        TCS   NaN  6000.0     Chennai       1
# 7    Infosys  23.0  7000.0      Mumbai       1
# 8        TCS  34.0  8000.0    Calcutta       1
# 9        CTS  45.0  9000.0       Delhi       0
# 10       CTS  23.0     NaN      Mumbai       0
# 11       CTS  34.0  1089.0    Calcutta       0
# 12       CTS  45.0     NaN     Chennai       0
# 13       CTS  18.0  1234.0      Mumbai       0
# 14   Infosys  40.0  3000.0    Calcutta       0
# 15       TCS  23.0  3000.0       Delhi       0
# 16   Infosys  23.0  3030.0  Podicherry       0
# 17       TCS  34.0  5000.0      Cochin       0
# 18       TCS  22.0     NaN     Chennai       0
# 19   Infosys  32.0     NaN      Mumbai       0
# 20       TCS  37.0  3045.0    Calcutta       0
# 21   Infosys  50.0  3184.0       Delhi       0
# 22       TCS  21.0  4824.0      Mumbai       0
# 23   Infosys   NaN  5835.0      Cochin       0
# 24       TCS   NaN  7084.0     Chennai       1
# 25   Infosys  23.0  8943.0      Mumbai       1
# 26       TCS  34.0  8345.0    Calcutta       1
# 27       CTS  45.0  9284.0       Delhi       1
# 28       CTS  23.0  9876.0      Mumbai       1
# 29       CTS  35.0  2034.0      Cochin       0
# ..       ...   ...     ...         ...     ...
# 115  Infosys  22.0  8787.0    Calcutta       0
# 116      TCS  33.0  8787.0         NaN       1
# 117      CTS  44.0  9876.0         NaN       1
# 118      CTS  22.0     NaN         NaN       0
# 119      CTS  33.0  1089.0       Noida       0
# 120      CTS  44.0     NaN   Hyderabad       0
# 121      CTS   0.0  1234.0    Calcutta       0
# 122  Infosys  44.0  3234.0      Mumbai       0
# 123      NaN   NaN  3454.0    Calcutta       0
# 124  Infosys  22.0  8787.0    Calcutta       1
# 125      TCS  33.0  5654.0         NaN       1
# 126      TCS  20.0  5009.0         NaN       1
# 127  Infosys  30.0  5098.0       Noida       0
# 128      TCS  33.0  3045.0   Hyderabad       0
# 129  Infosys  50.0  3184.0    Calcutta       0
# 132      TCS   NaN  7084.0      Cochin       1
# 133      NaN  22.0  8943.0     Chennai       0
# 134      TCS  31.0  8345.0      Mumbai       0
# 135      CTS  40.0  9284.0    Calcutta       1
# 136      NaN   NaN     NaN       Delhi       0
# 137      CTS  31.0  2034.0      Mumbai       0
# 138      CTS  44.0  3033.0      Cochin       0
# 139      CTS  22.0  2934.0       Noida       0
# 140  Infosys  44.0  4034.0   Hyderabad       0
# 141      TCS  33.0  5034.0    Calcutta       0
# 142  Infosys  22.0  8202.0      Mumbai       0
# 143      TCS  33.0  9024.0    Calcutta       1
# 145  Infosys  44.0  4034.0       Delhi       1
# 146      TCS  33.0  5034.0      Mumbai       1
# 147  Infosys  22.0  8202.0      Cochin       0
#
# [144 rows x 5 columns]

# %% [markdown]
# # Remove the row number 137

# %%
df.drop(137,axis=0)
# Out:
#      Company   Age  Salary        City Country  Gender
# 0        TCS  20.0     NaN     Chennai   India       0
# 1    Infosys  30.0     NaN      Mumbai   India       0
# 2        TCS  35.0  2300.0    Calcutta   India       0
# 3    Infosys  40.0  3000.0       Delhi   India       0
# 4        TCS  23.0  4000.0      Mumbai   India       0
# 5    Infosys   NaN  5000.0    Calcutta   India       0
# 6        TCS   NaN  6000.0     Chennai   India       1
# 7    Infosys  23.0  7000.0      Mumbai   India       1
# 8        TCS  34.0  8000.0    Calcutta   India       1
# 9        CTS  45.0  9000.0       Delhi   India       0
# 10       CTS  23.0     NaN      Mumbai   India       0
# 11       CTS  34.0  1089.0    Calcutta   India       0
# 12       CTS  45.0     NaN     Chennai   India       0
# 13       CTS  18.0  1234.0      Mumbai   India       0
# 14   Infosys  40.0  3000.0    Calcutta   India       0
# 15       TCS  23.0  3000.0       Delhi   India       0
# 16   Infosys  23.0  3030.0  Podicherry   India       0
# 17       TCS  34.0  5000.0      Cochin   India       0
# 18       TCS  22.0     NaN     Chennai   India       0
# 19   Infosys  32.0     NaN      Mumbai   India       0
# 20       TCS  37.0  3045.0    Calcutta   India       0
# 21   Infosys  50.0  3184.0       Delhi   India       0
# 22       TCS  21.0  4824.0      Mumbai   India       0
# 23   Infosys   NaN  5835.0      Cochin   India       0
# 24       TCS   NaN  7084.0     Chennai   India       1
# 25   Infosys  23.0  8943.0      Mumbai   India       1
# 26       TCS  34.0  8345.0    Calcutta   India       1
# 27       CTS  45.0  9284.0       Delhi   India       1
# 28       CTS  23.0  9876.0      Mumbai   India       1
# 29       CTS  35.0  2034.0      Cochin   India       0
# ..       ...   ...     ...         ...     ...     ...
# 114      TCS   NaN  5555.0      Mumbai   India       0
# 115  Infosys  22.0  8787.0    Calcutta   India       0
# 116      TCS  33.0  8787.0         NaN   India       1
# 117      CTS  44.0  9876.0         NaN   India       1
# 118      CTS  22.0     NaN         NaN   India       0
# 119      CTS  33.0  1089.0       Noida   India       0
# 120      CTS  44.0     NaN   Hyderabad   India       0
# 121      CTS   0.0  1234.0    Calcutta   India       0
# 122  Infosys  44.0  3234.0      Mumbai   India       0
# 123      NaN   NaN  3454.0    Calcutta   India       0
# 124  Infosys  22.0  8787.0    Calcutta   India       1
# 125      TCS  33.0  5654.0         NaN   India       1
# 126      TCS  20.0  5009.0         NaN   India       1
# 127  Infosys  30.0  5098.0       Noida   India       0
# 128      TCS  33.0  3045.0   Hyderabad   India       0
# 129  Infosys  50.0  3184.0    Calcutta   India       0
# 132      TCS   NaN  7084.0      Cochin   India       1
# 133      NaN  22.0  8943.0     Chennai   India       0
# 134      TCS  31.0  8345.0      Mumbai   India       0
# 135      CTS  40.0  9284.0    Calcutta   India       1
# 136      NaN   NaN     NaN       Delhi   India       0
# 138      CTS  44.0  3033.0      Cochin   India       0
# 139      CTS  22.0  2934.0       Noida   India       0
# 140  Infosys  44.0  4034.0   Hyderabad   India       0
# 141      TCS  33.0  5034.0    Calcutta   India       0
# 142  Infosys  22.0  8202.0      Mumbai   India       0
# 143      TCS  33.0  9024.0    Calcutta   India       1
# 145  Infosys  44.0  4034.0       Delhi   India       1
# 146      TCS  33.0  5034.0      Mumbai   India       1
# 147  Infosys  22.0  8202.0      Cochin   India       0
#
# [143 rows x 6 columns]

# %% [markdown]
# # Find number of each labels in Company

# %%
df['Company'].value_counts()
# Out:
# TCS        54
# Infosys    45
# CTS        37
# Name: Company, dtype: int64

# %% [markdown]
# # Find number of each labels in City

# %%
df['City'].value_counts(dropna=False)
# Out:
# Mumbai        34
# Calcutta      32
# Chennai       14
# Delhi         14
# NaN           14
# Cochin        12
# Noida          9
# Hyderabad      8
# Podicherry     3
# Pune           2
# Nagpur         1
# Bhopal         1
# Name: City, dtype: int64

# %% [markdown]
# # Find Number of Null Values in each column

# %%
df.apply(lambda z:z.isna().sum(),axis=0)
# Out:
# Company     8
# Age        17
# Salary     23
# City       14
# Country     0
# Gender      0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Company     8
# Age        17
# Salary     23
# City       14
# Country     0
# Gender      0
# dtype: int64

# %%
df[df.City.isna()]
# Out:
#      Company   Age  Salary City Country  Gender
# 33       TCS  36.0  5034.0  NaN   India       0
# 34   Infosys  26.0  8202.0  NaN   India       0
# 35       TCS  35.0  9024.0  NaN   India       1
# 41   Infosys   NaN  5000.0  NaN   India       0
# 42       TCS   NaN  6000.0  NaN   India       0
# 43   Infosys  25.0  7000.0  NaN   India       0
# 61       NaN  25.0  8943.0  NaN   India       1
# 62       TCS  36.0  8345.0  NaN   India       1
# 63       CTS  41.0  9284.0  NaN   India       1
# 116      TCS  33.0  8787.0  NaN   India       1
# 117      CTS  44.0  9876.0  NaN   India       1
# 118      CTS  22.0     NaN  NaN   India       0
# 125      TCS  33.0  5654.0  NaN   India       1
# 126      TCS  20.0  5009.0  NaN   India       1

# %% [markdown]
# # Remove all Null values in Salary

# %%
df.dropna(subset=['Salary'])
# Out:
#      Company   Age  Salary        City Country  Gender
# 2        TCS  35.0  2300.0    Calcutta   India       0
# 3    Infosys  40.0  3000.0       Delhi   India       0
# 4        TCS  23.0  4000.0      Mumbai   India       0
# 5    Infosys   NaN  5000.0    Calcutta   India       0
# 6        TCS   NaN  6000.0     Chennai   India       1
# 7    Infosys  23.0  7000.0      Mumbai   India       1
# 8        TCS  34.0  8000.0    Calcutta   India       1
# 9        CTS  45.0  9000.0       Delhi   India       0
# 11       CTS  34.0  1089.0    Calcutta   India       0
# 13       CTS  18.0  1234.0      Mumbai   India       0
# 14   Infosys  40.0  3000.0    Calcutta   India       0
# 15       TCS  23.0  3000.0       Delhi   India       0
# 16   Infosys  23.0  3030.0  Podicherry   India       0
# 17       TCS  34.0  5000.0      Cochin   India       0
# 20       TCS  37.0  3045.0    Calcutta   India       0
# 21   Infosys  50.0  3184.0       Delhi   India       0
# 22       TCS  21.0  4824.0      Mumbai   India       0
# 23   Infosys   NaN  5835.0      Cochin   India       0
# 24       TCS   NaN  7084.0     Chennai   India       1
# 25   Infosys  23.0  8943.0      Mumbai   India       1
# 26       TCS  34.0  8345.0    Calcutta   India       1
# 27       CTS  45.0  9284.0       Delhi   India       1
# 28       CTS  23.0  9876.0      Mumbai   India       1
# 29       CTS  35.0  2034.0      Cochin   India       0
# 30       CTS  46.0  7654.0     Chennai   India       0
# 31       CTS  20.0  2934.0      Mumbai   India       0
# 32   Infosys  45.0  4034.0    Calcutta   India       0
# 33       TCS  36.0  5034.0         NaN   India       0
# 34   Infosys  26.0  8202.0         NaN   India       0
# 35       TCS  35.0  9024.0         NaN   India       1
# ..       ...   ...     ...         ...     ...     ...
# 112      TCS  22.0  4324.0      Cochin   India       0
# 113  Infosys   NaN  5435.0     Chennai   India       0
# 114      TCS   NaN  5555.0      Mumbai   India       0
# 115  Infosys  22.0  8787.0    Calcutta   India       0
# 116      TCS  33.0  8787.0         NaN   India       1
# 117      CTS  44.0  9876.0         NaN   India       1
# 119      CTS  33.0  1089.0       Noida   India       0
# 121      CTS   0.0  1234.0    Calcutta   India       0
# 122  Infosys  44.0  3234.0      Mumbai   India       0
# 123      NaN   NaN  3454.0    Calcutta   India       0
# 124  Infosys  22.0  8787.0    Calcutta   India       1
# 125      TCS  33.0  5654.0         NaN   India       1
# 126      TCS  20.0  5009.0         NaN   India       1
# 127  Infosys  30.0  5098.0       Noida   India       0
# 128      TCS  33.0  3045.0   Hyderabad   India       0
# 129  Infosys  50.0  3184.0    Calcutta   India       0
# 132      TCS   NaN  7084.0      Cochin   India       1
# 133      NaN  22.0  8943.0     Chennai   India       0
# 134      TCS  31.0  8345.0      Mumbai   India       0
# 135      CTS  40.0  9284.0    Calcutta   India       1
# 137      CTS  31.0  2034.0      Mumbai   India       0
# 138      CTS  44.0  3033.0      Cochin   India       0
# 139      CTS  22.0  2934.0       Noida   India       0
# 140  Infosys  44.0  4034.0   Hyderabad   India       0
# 141      TCS  33.0  5034.0    Calcutta   India       0
# 142  Infosys  22.0  8202.0      Mumbai   India       0
# 143      TCS  33.0  9024.0    Calcutta   India       1
# 145  Infosys  44.0  4034.0       Delhi   India       1
# 146      TCS  33.0  5034.0      Mumbai   India       1
# 147  Infosys  22.0  8202.0      Cochin   India       0
#
# [121 rows x 6 columns]

# %% [markdown]
# # Replace the Null values in Company with mode

# %%
df['Company'].fillna(df['Company'].mode()[0],inplace=True)

# %% [markdown]
# # Replace the null value in Salary with median

# %%
df['Salary'].fillna(df['Salary'].median(),inplace=True)

# %% [markdown]
# # Replace the null value in age with mean

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %% [markdown]
# # Filter the data with age>40 and Salary<5000

# %%
df.loc[(df['Age']>40) & (df['Salary']<5000)]
# Out:
#      Company   Age  Salary       City Country  Gender
# 21   Infosys  50.0  3184.0      Delhi   India       0
# 32   Infosys  45.0  4034.0   Calcutta   India       0
# 39   Infosys  41.0  3000.0     Mumbai   India       0
# 50   Infosys  41.0  3000.0    Chennai   India       0
# 57   Infosys  51.0  3184.0  Hyderabad   India       0
# 68   Infosys  43.0  4034.0     Mumbai   India       0
# 75   Infosys  44.0  3000.0     Cochin   India       0
# 86   Infosys  41.0  3000.0      Delhi   India       0
# 93   Infosys  54.0  3184.0     Mumbai   India       0
# 104  Infosys  44.0  4034.0      Delhi   India       0
# 122  Infosys  44.0  3234.0     Mumbai   India       0
# 129  Infosys  50.0  3184.0   Calcutta   India       0
# 138      CTS  44.0  3033.0     Cochin   India       0
# 140  Infosys  44.0  4034.0  Hyderabad   India       0
# 145  Infosys  44.0  4034.0      Delhi   India       1

# %% [markdown]
# # Draw an histogram chart for age, Salary

# %%
# %matplotlib inline
df[['Age','Salary']].plot(kind='hist',grid=True)

# %%
# print(df['Age'].value_counts())

# %% [markdown]
# # Draw the pie chart for place and Company

# %%
# df['Company'].plot('City',kind='pie')

# %%
# df.plot(y=df.City,x=df.Company,kind='pie',subplots=True)

# %%
# df[df['City'].isna()]

# %%
df['City'].fillna(df['City'].mode()[0],inplace=True)

# %%
df[df['City'].isna()]
# Out:
# Empty DataFrame
# Columns: [Company, Age, Salary, City, Country, Gender]
# Index: []

# %%
x = df['City'].value_counts(dropna=False)
x
# Out:
# Mumbai        48
# Calcutta      32
# Chennai       14
# Delhi         14
# Cochin        12
# Noida          9
# Hyderabad      8
# Podicherry     3
# Pune           2
# Nagpur         1
# Bhopal         1
# Name: City, dtype: int64

# %%
df['City'].unique()
# Out:
# array(['Chennai', 'Mumbai', 'Calcutta', 'Delhi', 'Podicherry', 'Cochin',
#        'Noida', 'Hyderabad', 'Bhopal', 'Nagpur', 'Pune'], dtype=object)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(8, 8))
plt.pie(x = df.City.value_counts(dropna=False),labeldistance=1.3,labels=x.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x1beca2adf98>,
#   <matplotlib.patches.Wedge at 0x1beca2b54a8>,
#   <matplotlib.patches.Wedge at 0x1beca2b5978>,
#   <matplotlib.patches.Wedge at 0x1beca2b5e48>,
#   <matplotlib.patches.Wedge at 0x1beca2be358>,
#   <matplotlib.patches.Wedge at 0x1beca2be828>,
#   <matplotlib.patches.Wedge at 0x1beca2becf8>,
#   <matplotlib.patches.Wedge at 0x1beca2c8208>,
#   <matplotlib.patches.Wedge at 0x1beca2c86d8>,
#   <matplotlib.patches.Wedge at 0x1beca2c8ba8>,
#   <matplotlib.patches.Wedge at 0x1beca281ba8>],
#  [Text(0.6499999648639682, 1.125833045205567, 'Mumbai'),
#   Text(-1.2216004370870006, 0.44462610371957384, 'Calcutta'),
#   Text(-1.0313592806325476, -0.79138993818036, 'Chennai'),
#   Text(-0.39091742972307, -1.2398320705396795, 'Delhi'),
#   Text(0.3364648859980161, -1.2557035400485028, 'Cochin'),
#   Text(0.8571496663917741, -0.9773916560951759, 'Noida'),
#   Text(1.1531141494808308, -0.6002730697500099, 'Hyderabad'),
#   Text(1.2627447259150806, -0.3089915163457535, 'Podicherry'),
#   Text(1.2888783394791647, -0.16968390030121008, 'Pune'),
#   Text(1.2972166101193745, -0.08502391681402982, 'Nagpur'),
#   Text(1.2996906385182558, -0.0283591986489152, 'Bhopal')])

# %%
df.Company.value_counts()
# Out:
# TCS        62
# Infosys    45
# CTS        37
# Name: Company, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(7, 7))
x = df.Company.value_counts()
plt.pie(x = df.Company.value_counts(),labels= x.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x1beca30d748>,
#   <matplotlib.patches.Wedge at 0x1beca30dc88>,
#   <matplotlib.patches.Wedge at 0x1beca317198>],
#  [Text(0.23808358650393224, 1.0739256053551498, 'TCS'),
#   Text(-0.9404030696131664, -0.5706505644105981, 'Infosys'),
#   Text(0.7606643530942899, -0.7946003661789022, 'CTS')])

# %% [markdown]
# # Find the mean, count, median of salary with repective to the place

# %%
d1 = df.groupby('City')['Salary'].mean()
d2 = df.groupby('City')['Salary'].count()
d3 = df.groupby('City')['Salary'].median()
res = pd.DataFrame([d1,d2,d3],index=['mean','count','median'])
res.T
# Out:
#                    mean  count  median
# City
# Bhopal      7000.000000    1.0  7000.0
# Calcutta    4910.906250   32.0  4912.0
# Chennai     5876.142857   14.0  5635.0
# Cochin      5053.000000   12.0  5017.0
# Delhi       4801.857143   14.0  4034.0
# Hyderabad   4537.125000    8.0  4517.0
# Mumbai      5555.604167   48.0  5004.5
# Nagpur      8000.000000    1.0  8000.0
# Noida       4523.222222    9.0  5000.0
# Podicherry  4782.666667    3.0  3030.0
# Pune        7000.000000    2.0  7000.0

# %% [markdown]
# # Find the mean age with repective to the Company

# %%
df.groupby('Company')['Age'].mean()
# Out:
# Company
# CTS        31.324324
# Infosys    32.037620
# TCS        28.956058
# Name: Age, dtype: float64

# %% [markdown]
# # END
